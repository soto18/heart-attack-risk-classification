# %%
import pandas as pd

# %% [markdown]
# ##### Cambiar valores de columnas a valores numéricos

# %%
df_data = pd.read_csv("process_dataset/02_second_result.csv")
df_data
# Out:
#       Age     Sex  Cholesterol  Heart Rate  Diabetes  Family History  Obesity  \
# 0      19  Female          143          51         1               0        0
# 1      33    Male          170          46         1               1        0
# 2      85    Male          201         105         0               0        1
# 3      37  Female          150          87         0               0        0
# 4      18  Female          233          74         0               1        0
# ...   ...     ...          ...         ...       ...             ...      ...
# 6273   80    Male          151         108         1               0        1
# 6274   27  Female          396          79         1               0        0
# 6275   44  Female          339          85         1               0        1
# 6276   70    Male          123          76         0               1        0
# 6277   65    Male          331          44         1               0        0
#
# ...

# %%
df_data.dtypes
# Out:
# Age                                  int64
# Sex                                 object
# Cholesterol                          int64
# Heart Rate                           int64
# Diabetes                             int64
# Family History                       int64
# Obesity                              int64
# Alcohol Consumption                  int64
# Exercise Hours Per Week            float64
# Diet                                object
# Previous Heart Problems              int64
# Medication Use                       int64
# Stress Level                         int64
# Sedentary Hours Per Day            float64
# Income                               int64
# BMI                                float64
# Triglycerides                        int64
# Physical Activity Days Per Week      int64
# Sleep Hours Per Day                  int64
# Continent                           object
# Heart Attack Risk                    int64
# Systolic                             int64
# ...

# %% [markdown]
# ##### Codificación con one-hot
# - Trata todas las categorías de manera equitativa, evitando que el modelo aprenda relaciones incorrectas entre ellas.
# - Facilita la interpretación

# %%
df_data = pd.get_dummies(df_data, columns=['Sex', 'Diet', 'Continent'])
df_data[df_data.select_dtypes(include='bool').columns] = df_data.select_dtypes(include='bool').apply(lambda x: x.astype(int))

# %%
df_data.head(5)
# Out:
#    Age  Cholesterol  Heart Rate  Diabetes  Family History  Obesity  \
# 0   19          143          51         1               0        0
# 1   33          170          46         1               1        0
# 2   85          201         105         0               0        1
# 3   37          150          87         0               0        0
# 4   18          233          74         0               1        0
#
#    Alcohol Consumption  Exercise Hours Per Week  Previous Heart Problems  \
# 0                    0                16.978907                        0
# 1                    1                 2.210484                        0
# 2                    1                12.466069                        1
# 3                    1                 7.893431                        1
# 4                    1                18.571328                        1
#
#    Medication Use  ...  Sex_Male  Diet_Average  Diet_Healthy  Diet_Unhealthy  \
# ...

# %%
df_data.to_csv("process_dataset/05_fifth_result.csv", index=False)
