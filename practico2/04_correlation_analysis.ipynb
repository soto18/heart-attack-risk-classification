# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_data = pd.read_csv("process_dataset/03_third_result.csv")
df_data
# Out:
#       Age  Cholesterol  Heart Rate  Diabetes  Family History  Obesity  \
# 0      19          143          51         1               0        0
# 1      33          170          46         1               1        0
# 2      37          150          87         0               0        0
# 3      18          233          74         0               1        0
# 4      35          376          88         0               0        1
# ...   ...          ...         ...       ...             ...      ...
# 5645   80          151         108         1               0        1
# 5646   27          396          79         1               0        0
# 5647   44          339          85         1               0        1
# 5648   70          123          76         0               1        0
# 5649   65          331          44         1               0        0
#
#       Alcohol Consumption  Exercise Hours Per Week  Previous Heart Problems  \
# ...

# %%
custom_palette = ["#F1948A", "#85C1E9"]
colors = sns.color_palette(custom_palette)

correlation_matrix = df_data[['Age', 'Heart Rate', 'Diabetes', 'Family History', 'Obesity',
                               'Cholesterol', 'Alcohol Consumption', 'Exercise Hours Per Week',
                               'Previous Heart Problems', 'Medication Use', 'Stress Level',
                               'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
                               'Physical Activity Days Per Week', 'Sleep Hours Per Day', 
                               'Heart Attack Risk']].corr()

plt.figure(figsize=(19, 10))
sns.heatmap(correlation_matrix, 
            cmap=sns.light_palette(custom_palette[0], as_cmap=True), 
            annot=True, 
            fmt=".2f",  
            cbar_kws={"shrink": .8})
plt.xticks(rotation=90, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
relevant_features = correlation_matrix['Heart Attack Risk'].sort_values(ascending=False)

# %%
relevant_features
# Out:
# Heart Attack Risk                  1.000000
# Diabetes                           0.032412
# Income                             0.026397
# Cholesterol                        0.018870
# Triglycerides                      0.013167
# Exercise Hours Per Week            0.012711
# BMI                                0.008334
# Medication Use                     0.007709
# Physical Activity Days Per Week    0.002893
# Previous Heart Problems            0.002457
# Family History                     0.000270
# Age                               -0.002067
# Sedentary Hours Per Day           -0.011062
# Alcohol Consumption               -0.011808
# Heart Rate                        -0.013111
# Obesity                           -0.016617
# Stress Level                      -0.018290
# Sleep Hours Per Day               -0.020322
# Name: Heart Attack Risk, dtype: float64

# %% [markdown]
# - El riesgo de ataque cardíaco tiene la mayor correlación con la diabetes, el nivel de colesterol y las horas de ejercicio por día
# - Las horas de sueño por día, el consumo de alcohol y la obesidad no muestran un vínculo fuerte con el riesgo de ataque cardíaco
