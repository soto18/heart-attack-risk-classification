# %%
import pandas as pd
import numpy as np
from sklearn.metrics import make_scorer, accuracy_score, recall_score, precision_score, f1_score
from sklearn.model_selection import cross_val_score

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.experimental import enable_halving_search_cv  # Necesario para habilitar HalvingGridSearchCV
from sklearn.model_selection import HalvingGridSearchCV
import optuna

# %%
df_data = pd.read_csv("process_dataset/train_data_scaled_robust.csv")
response = np.load("process_dataset/y_train.npy")

# %%
# Definir las métricas a evaluar
scoring = {
    'accuracy': 'accuracy',
    'recall': 'recall',
    'precision': 'precision',
    'f1': 'f1'
}

# %% [markdown]
# #### Optimización usando GridSearch

# %%
parameters = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

model = KNeighborsClassifier()
clf = GridSearchCV(model, parameters, cv=10, scoring=scoring, refit='recall')
clf.fit(df_data, response)
results = clf.cv_results_

print("Best Parameters:", clf.best_params_)
print("Best Accuracy Score:", clf.best_score_)

# Extraer las métricas de la mejor combinación de parámetros
best_index = clf.best_index_  # Índice de la mejor combinación
print("Metrics for best model:")
print("Accuracy:", results['mean_test_accuracy'][best_index])
print("Recall:", results['mean_test_recall'][best_index])
print("Precision:", results['mean_test_precision'][best_index])
print("F1 Score:", results['mean_test_f1'][best_index])
# Out:
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# Best Accuracy Score: 0.4869813759948289
# Metrics for best model:
# Accuracy: 0.5050884955752212
# Recall: 0.4869813759948289
# Precision: 0.4971935303492526
# F1 Score: 0.49163991721166234

# %% [markdown]
# #### Optimización usando HalvingGridSearch

# %%
parameters = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

model = KNeighborsClassifier()

# Configurar el HalvingGridSearchCV
clf = HalvingGridSearchCV(model, parameters)
clf.fit(df_data, response)

print("Best Parameters:", clf.best_params_)
print("Best Score:", clf.best_score_)
# Out:
# /home/nicole/miniconda3/lib/python3.12/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}
# Best Score: 0.49612403100775193

# %% [markdown]
# #### Optimización bayesiana (Optuna)

# %%
results = []

def objective(trial):
    n_neighbors = trial.suggest_int('n_neighbors', 3, 9)
    weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
    metric = trial.suggest_categorical('metric', ['euclidean', 'manhattan'])

    model = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights, metric=metric)

    accuracy = cross_val_score(model, df_data, response, cv=10, scoring='accuracy').mean()
    recall = cross_val_score(model, df_data, response, cv=10, scoring='recall').mean()
    precision = cross_val_score(model, df_data, response, cv=10, scoring='precision').mean()
    f1 = cross_val_score(model, df_data, response, cv=10, scoring='f1').mean()

    metrics = {
        "Model": f"KNN(n_neighbors={n_neighbors}, weights={weights}, metric={metric})",
        "Accuracy": accuracy,
        "Recall": recall,
        "Precision": precision,
        "F1": f1
    }
    results.append(metrics)

    return precision

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

df_results = pd.DataFrame(results)

print("Best Parameters:", study.best_params)
print("Best Recall F1:", study.best_value)
# Out:
# [I 2024-10-21 01:13:40,726] A new study created in memory with name: no-name-49eaa806-77e4-489e-8e70-9ad9c8bbedd7
# [I 2024-10-21 01:13:41,313] Trial 0 finished with value: 0.48225444188008126 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 0 with value: 0.48225444188008126.
# [I 2024-10-21 01:13:42,482] Trial 1 finished with value: 0.4899224283634223 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 1 with value: 0.4899224283634223.
# [I 2024-10-21 01:13:42,966] Trial 2 finished with value: 0.48050445867597497 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 1 with value: 0.4899224283634223.
# [I 2024-10-21 01:13:43,937] Trial 3 finished with value: 0.49428318956048534 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial
and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:36,420] Trial 57 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:37,291] Trial 58 finished with value: 0.49644611079193907 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:38,147] Trial 59 finished with value: 0.49428318956048534 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:38,994] Trial 60 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:40,154] Trial 61 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:41,083] Trial 62 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:41,897] Trial 63 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:42,732] Trial 64 finished with value: 0.49196160089883867 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:43,540] Trial 65 finished with value: 0.49644611079193907 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:44,551] Trial 66 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:46,540] Trial 67 finished with value: 0.49350299988629837 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:47,212] Trial 68 finished with value: 0.48448703857157005 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'euclidean'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:48,107] Trial 69 finished with value: 0.49196160089883867 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:48,898] Trial 70 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:50,146] Trial 71 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:51,070] Trial 72 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:51,948] Trial 73 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:52,839] Trial 74 finished with value: 0.49196160089883867 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:53,685] Trial 75 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:54,739] Trial 76 finished with value: 0.49644611079193907 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:55,846] Trial 77 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:56,957] Trial 78 finished with value: 0.4899224283634223 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'euclidean'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:57,819] Trial 79 finished with value: 0.49644611079193907 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:14:58,775] Trial 80 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:15:00,060] Trial 81 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:15:00,941] Trial 82 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:15:01,812] Trial 83 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:15:02,958] Trial 84 finished with value: 0.49196160089883867 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:15:04,319] Trial 85 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:15:05,779] Trial 86 finished with value: 0.49644611079193907 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:15:06,831] Trial 87 finished with value: 0.4971935303492526 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:15:07,663] Trial 88 finished with value: 0.49196160089883867 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'metric': 'manhattan'}. Best is trial 19 with value: 0.4971935303492526.
# [I 2024-10-21 01:15:09,529] Trial 89 finished with value: 0.4972149920203851 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 89 with value: 0.4972149920203851.
# [I 2024-10-21 01:15:11,613] Trial 90 finished with value: 0.49350299988629837 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 89 with value: 0.4972149920203851.
# [I 2024-10-21 01:15:13,139] Trial 91 finished with value: 0.4972149920203851 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 89 with value: 0.4972149920203851.
# [I 2024-10-21 01:15:14,778] Trial 92 finished with value: 0.4972149920203851 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 89 with value: 0.4972149920203851.
# [I 2024-10-21 01:15:16,600] Trial 93 finished with value: 0.4972149920203851 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 89 with value: 0.4972149920203851.
# [I 2024-10-21 01:15:18,677] Trial 94 finished with value: 0.4972149920203851 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 89 with value: 0.4972149920203851.
# [I 2024-10-21 01:15:20,685] Trial 95 finished with value: 0.4972149920203851 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 89 with value: 0.4972149920203851.
# [I 2024-10-21 01:15:23,355] Trial 96 finished with value: 0.4972149920203851 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 89 with value: 0.4972149920203851.
# [I 2024-10-21 01:15:25,270] Trial 97 finished with value: 0.4972149920203851 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 89 with value: 0.4972149920203851.
# [I 2024-10-21 01:15:26,847] Trial 98 finished with value: 0.4972149920203851 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 89 with value: 0.4972149920203851.
# [I 2024-10-21 01:15:28,854] Trial 99 finished with value: 0.4972149920203851 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}. Best is trial 89 with value: 0.4972149920203851.
# Best Parameters: {'n_neighbors': 5, 'weights': 'uniform', 'metric': 'manhattan'}
# Best Recall Score: 0.4972149920203851

# %%
df_results.sort_values(by="F1", ascending=False)
# Out:
#                                                 Model  Accuracy    Recall  \
# 77  KNN(n_neighbors=5, weights=distance, metric=ma...  0.505088  0.486981
# 71  KNN(n_neighbors=5, weights=distance, metric=ma...  0.505088  0.486981
# 20  KNN(n_neighbors=5, weights=distance, metric=ma...  0.505088  0.486981
# 21  KNN(n_neighbors=5, weights=distance, metric=ma...  0.505088  0.486981
# 22  KNN(n_neighbors=5, weights=distance, metric=ma...  0.505088  0.486981
# ..                                                ...       ...       ...
# 46  KNN(n_neighbors=6, weights=uniform, metric=euc...  0.493584  0.300553
# 5   KNN(n_neighbors=4, weights=uniform, metric=euc...  0.501770  0.294694
# 56  KNN(n_neighbors=4, weights=uniform, metric=euc...  0.501770  0.294694
# 1   KNN(n_neighbors=4, weights=uniform, metric=euc...  0.501770  0.294694
# 78  KNN(n_neighbors=4, weights=uniform, metric=euc...  0.501770  0.294694
#
#     Precision        F1
# 77   0.497194  0.491640
# 71   0.497194  0.491640
# 20   0.497194  0.491640
# 21   0.497194  0.491640
# 22   0.497194  0.491640
# ..        ...       ...
# 46   0.476347  0.367902
# 5    0.489922  0.367674
# 56   0.489922  0.367674
# 1    0.489922  0.367674
# 78   0.489922  0.367674
#
# [100 rows x 5 columns]
