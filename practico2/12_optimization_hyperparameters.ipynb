# %%
import pandas as pd
import numpy as np
from sklearn.metrics import make_scorer, accuracy_score, recall_score, precision_score, f1_score
from sklearn.model_selection import cross_val_score

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.experimental import enable_halving_search_cv  # Necesario para habilitar HalvingGridSearchCV
from sklearn.model_selection import HalvingGridSearchCV
import optuna

# %%
df_data = pd.read_csv("process_dataset/train_data_scaled_robust.csv")
response = np.load("process_dataset/y_train.npy")

# %%
# Definir las métricas a evaluar
scoring = {
    'accuracy': 'accuracy',
    'recall': 'recall',
    'precision': 'precision',
    'f1': 'f1'
}

parameters = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'splitter': ['best', 'random'],
    'max_depth': [3, 4, 5, 7, 9, 11, 15]
}

# %% [markdown]
# #### Optimización usando GridSearch

# %%
model = DecisionTreeClassifier()
clf = GridSearchCV(model, parameters, cv=10, scoring=scoring, refit='recall')
clf.fit(df_data, response)
results = clf.cv_results_

print("Best Parameters:", clf.best_params_)
print("Best Accuracy Score:", clf.best_score_)

# Extraer las métricas de la mejor combinación de parámetros
best_index = clf.best_index_  # Índice de la mejor combinación
print("Metrics for best model:")
print("Accuracy:", results['mean_test_accuracy'][best_index])
print("Recall:", results['mean_test_recall'][best_index])
print("Precision:", results['mean_test_precision'][best_index])
print("F1 Score:", results['mean_test_f1'][best_index])
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': 7, 'splitter': 'random'}
# Best Accuracy Score: 0.4883024279885266
# Metrics for best model:
# Accuracy: 0.4984513274336283
# Recall: 0.4883024279885266
# Precision: 0.48995989758832686
# F1 Score: 0.4867925227930125

# %% [markdown]
# #### Optimización usando HalvingGridSearch

# %%
model = DecisionTreeClassifier()

# Configurar el HalvingGridSearchCV
clf = HalvingGridSearchCV(model, parameters)
clf.fit(df_data, response)

print("Best Parameters:", clf.best_params_)
print("Best Score:", clf.best_score_)
# Out:
# Best Parameters: {'criterion': 'log_loss', 'max_depth': 7, 'splitter': 'best'}
# Best Score: 0.5047724750277469
# /home/nsoto/miniconda3/envs/ml/lib/python3.13/site-packages/numpy/ma/core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %% [markdown]
# #### Optimización bayesiana (Optuna)

# %%
results = []

def objective(trial):
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy', 'log_loss']) 
    splitter = trial.suggest_categorical('splitter', ['best', 'random'])
    max_depth = trial.suggest_int('max_depth', 3, 15) 

    model = DecisionTreeClassifier(criterion=criterion, splitter=splitter, max_depth=max_depth)

    accuracy = cross_val_score(model, df_data, response, cv=10, scoring='accuracy').mean()
    recall = cross_val_score(model, df_data, response, cv=10, scoring='recall').mean()
    precision = cross_val_score(model, df_data, response, cv=10, scoring='precision').mean()
    f1 = cross_val_score(model, df_data, response, cv=10, scoring='f1').mean()

    metrics = {
        "Model": f"DT(Criterion={criterion}, splitter={splitter}, max_depth={max_depth})",
        "Accuracy": accuracy,
        "Recall": recall,
        "Precision": precision,
        "F1": f1
    }
    results.append(metrics)

    return precision  # Retorna una métrica que deseas maximizar

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 3}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:02,928] Trial 81 finished with value: 0.4977348340733358 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 9}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:04,155] Trial 82 finished with value: 0.48294307579138207 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 8}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:05,542] Trial 83 finished with value: 0.4994261202298144 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 9}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:07,490] Trial 84 finished with value: 0.48885279067748033 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 14}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:09,127] Trial 85 finished with value: 0.49905845593118797 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 11}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:11,178] Trial 86 finished with value: 0.5027542338117511 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 15}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:13,281] Trial 87 finished with value: 0.5023036976874111 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 15}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:13,910] Trial 88 finished with value: 0.49262383723260106 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 15}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:16,010] Trial 89 finished with value: 0.5014198692396056 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 15}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:17,996] Trial 90 finished with value: 0.4902344759616063 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 14}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:20,099] Trial 91 finished with value: 0.4999590523450587 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 15}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:22,209] Trial 92 finished with value: 0.4994310995177472 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 15}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:24,140] Trial 93 finished with value: 0.49416038370873683 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 14}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:26,166] Trial 94 finished with value: 0.48859876701372074 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 14}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:28,086] Trial 95 finished with value: 0.4983705554005139 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 13}. Best is trial 29 with value: 0.5038590985891266.
# [I 2024-10-22 12:40:30,136] Trial 96 finished with value: 0.5040357395224253 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 15}. Best is trial 96 with value: 0.5040357395224253.
# [I 2024-10-22 12:40:32,249] Trial 97 finished with value: 0.5010225787691482 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 15}. Best is trial 96 with value: 0.5040357395224253.
# [I 2024-10-22 12:40:34,826] Trial 98 finished with value: 0.49630042407854325 and parameters: {'criterion': 'log_loss', 'splitter': 'best', 'max_depth': 15}. Best is trial 96 with value: 0.5040357395224253.
# [I 2024-10-22 12:40:36,788] Trial 99 finished with value: 0.488262088066662 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 14}. Best is trial 96 with value: 0.5040357395224253.
# Best Parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 15}
# Best Precision: 0.5040357395224253

# %%
df_results.sort_values(by="Recall", ascending=False)
# Out:
#                                                 Model  Accuracy    Recall  \
# 78  DT(Criterion=log_loss, splitter=random, max_de...  0.508628  0.494251
# 24  DT(Criterion=entropy, splitter=random, max_dep...  0.508628  0.491930
# 88  DT(Criterion=gini, splitter=random, max_depth=15)  0.495354  0.486549
# 23  DT(Criterion=entropy, splitter=random, max_dep...  0.499779  0.482028
# 22  DT(Criterion=entropy, splitter=random, max_dep...  0.494690  0.479326
# ..                                                ...       ...       ...
# 68  DT(Criterion=log_loss, splitter=best, max_dept...  0.494469  0.354862
# 44     DT(Criterion=gini, splitter=best, max_depth=7)  0.505310  0.353935
# 37     DT(Criterion=gini, splitter=best, max_depth=6)  0.499558  0.349939
# 45     DT(Criterion=gini, splitter=best, max_depth=6)  0.500000  0.349039
# 4   DT(Criterion=entropy, splitter=best, max_depth=7)  0.496239  0.313239
#
#     Precision        F1
# 78   0.491072  0.463320
# 24   0.486073  0.489503
# 88   0.492624  0.490145
# 23   0.483970  0.468985
# 22   0.496971  0.500942
# ..        ...       ...
# 68   0.484882  0.404644
# 44   0.499109  0.408782
# 37   0.491443  0.394841
# 45   0.490017  0.394825
# 4    0.484524  0.371817
#
# [100 rows x 5 columns]
