# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Evaluar metricas de desempeño de los modelos

# %%
import pandas as pd
from joblib import load
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, matthews_corrcoef, confusion_matrix

# %%
def predict_class(scaler_instance, model, val_data, test_data):
    val_data_scaler = scaler_instance.transform(val_data.values)
    test_data_scaler = scaler_instance.transform(test_data.values)
    predict_val = model.predict(X=val_data_scaler)
    predict_test = model.predict(X=test_data_scaler)

    return predict_val, predict_test

# %%
def metrics_model(predict_val, y_val, dataset, scaler, model):
    acc_value = accuracy_score(y_pred=predict_val, y_true=y_val) 
    recall_value = recall_score(y_pred=predict_val, y_true=y_val, average='weighted')
    precision_value = precision_score(y_pred=predict_val, y_true=y_val, average='weighted') 
    f1_value = f1_score(y_pred=predict_val, y_true=y_val, average='weighted')
    mcc_value = matthews_corrcoef(y_pred=predict_val, y_true=y_val)
    cm = confusion_matrix(y_pred=predict_val, y_true=y_val)

    df_metrics = pd.DataFrame([[dataset, scaler, model, acc_value, recall_value, precision_value, f1_value, mcc_value, cm]],
                              columns=["dataset", "scaler", "model", "acc", "recall", "precision", "f1", "mcc", "cm"])

    return df_metrics

# %% [markdown]
# ##### Cargar escaladores

# %%
scalers = {
    "StandardScaler": load("results/scaler_standard.joblib"),
    "MinMaxScaler": load("results/scaler_min_max.joblib"),
    "RobustScaler": load("results/scaler_robust.joblib")
}

# %% [markdown]
# ##### Cargar modelos entrenados

# %%
models = {
    "RL": load("results/regression_model.joblib"),
    "KNN": load("results/knn_model.joblib"),
    "RF": load("results/rf_model.joblib"),
    "SVM": load("results/svm_model.joblib"),
    "DT": load("results/dt_model.joblib"),
    "AdaBoost": load("results/ada_model.joblib")
}

# %% [markdown]
# ##### Leer datos y respuestas de validación y testeo

# %%
val_data = pd.read_csv("process_dataset/val_data.csv")
test_data = pd.read_csv("process_dataset/test_data.csv")

y_val = np.load("process_dataset/y_val.npy")
y_test = np.load("process_dataset/y_test.npy")

# %% [markdown]
# ##### Aplicar metricas a los modelos con diferentes escaladores

# %%
results = []

for scaler_name, scaler_instance in scalers.items():
    for model_name, model in models.items():
        predict_val, predict_test = predict_class(scaler_instance, model, val_data, test_data)
        results.append(metrics_model(predict_val, y_val, "Validation", scaler_name, model_name))
        results.append(metrics_model(predict_test, y_test, "Test", scaler_name, model_name))

# %%
df_result = pd.concat(results)
df_result = df_result.reset_index(drop=True)

# %%
df_result
# Out:
#        dataset          scaler     model       acc    recall  precision  \
# 0   Validation  StandardScaler        RL  0.652091  0.652091   0.425223
# 1         Test  StandardScaler        RL  0.638540  0.638540   0.407734
# 2   Validation  StandardScaler       KNN  0.576679  0.576679   0.541256
# 3         Test  StandardScaler       KNN  0.565564  0.565564   0.535881
# 4   Validation  StandardScaler        RF  0.642586  0.642586   0.523706
# 5         Test  StandardScaler        RF  0.630559  0.630559   0.527780
# 6   Validation  StandardScaler       SVM  0.652091  0.652091   0.425223
# 7         Test  StandardScaler       SVM  0.639681  0.639681   0.769659
# 8   Validation  StandardScaler        DT  0.534221  0.534221   0.542182
# 9         Test  StandardScaler        DT  0.533637  0.533637   0.541494
# 10  Validation  StandardScaler  AdaBoost  0.644487  0.644487   0.533467
# 11        Test  StandardScaler  AdaBoost  0.629418  0.629418   0.527715
# 12  Validation    MinMaxScaler        RL  0.652091  0.652091   0.425223
# 13        Test    MinMaxScaler        RL  0.638540  0.638540   0.407734
# 14  Validation    MinMaxScaler       KNN  0.637516  0.637516   0.555115
# 15        Test    MinMaxScaler       KNN  0.627138  0.627138   0.543694
# 16  Validation    MinMaxScaler        RF  0.652091  0.652091   0.425223
# 17        Test    MinMaxScaler        RF  0.638540  0.638540   0.407734
# 18  Validation    MinMaxScaler       SVM  0.652091  0.652091   0.425223
# 19        Test    MinMaxScaler       SVM  0.638540  0.638540   0.407734
# 20  Validation    MinMaxScaler        DT  0.577313  0.577313   0.550149
# 21        Test    MinMaxScaler        DT  0.570125  0.570125   0.546539
# 22  Validation    MinMaxScaler  AdaBoost  0.652091  0.652091   0.425223
# 23        Test    MinMaxScaler  AdaBoost  0.638540  0.638540   0.407734
# 24  Validation    RobustScaler        RL  0.652091  0.652091   0.425223
# 25        Test    RobustScaler        RL  0.638540  0.638540   0.407734
# 26  Validation    RobustScaler       KNN  0.571610  0.571610   0.541360
# 27        Test    RobustScaler       KNN  0.562144  0.562144   0.529337
# 28  Validation    RobustScaler        RF  0.652091  0.652091   0.425223
# 29        Test    RobustScaler        RF  0.637400  0.637400   0.407470
# 30  Validation    RobustScaler       SVM  0.652091  0.652091   0.425223
# 31        Test    RobustScaler       SVM  0.638540  0.638540   0.407734
# 32  Validation    RobustScaler        DT  0.550697  0.550697   0.539908
# 33        Test    RobustScaler        DT  0.532497  0.532497   0.519139
# 34  Validation    RobustScaler  AdaBoost  0.652091  0.652091   0.425223
# 35        Test    RobustScaler  AdaBoost  0.638540  0.638540   0.407734
#
#           f1       mcc                        cm
# 0   0.514769  0.000000     [[1029, 0], [549, 0]]
# 1   0.497679  0.000000      [[560, 0], [317, 0]]
# 2   0.552201 -0.010619  [[785, 244], [424, 125]]
# 3   0.544878 -0.005262   [[416, 144], [237, 80]]
# 4   0.521012 -0.019666   [[1004, 25], [539, 10]]
# 5   0.507405 -0.009170     [[546, 14], [310, 7]]
# 6   0.514769  0.000000     [[1029, 0], [549, 0]]
# 7   0.500299  0.044907      [[560, 0], [316, 1]]
# 8   0.537870 -0.008981  [[641, 388], [347, 202]]
# 9   0.537160  0.006719  [[343, 217], [192, 125]]
# 10  0.522000 -0.010695   [[1007, 22], [539, 10]]
# 11  0.508632 -0.009820     [[544, 16], [309, 8]]
# 12  0.514769  0.000000     [[1029, 0], [549, 0]]
# 13  0.497679  0.000000      [[560, 0], [317, 0]]
# 14  0.539950  0.011743    [[973, 56], [516, 33]]
# 15  0.519450  0.006161    [[535, 25], [302, 15]]
# 16  0.514769  0.000000     [[1029, 0], [549, 0]]
# 17  0.497679  0.000000      [[560, 0], [317, 0]]
# 18  0.514769  0.000000     [[1029, 0], [549, 0]]
# 19  0.497679  0.000000      [[560, 0], [317, 0]]
# 20  0.559398  0.008367  [[767, 262], [405, 144]]
# 21  0.554239  0.017300   [[410, 150], [227, 90]]
# 22  0.514769  0.000000     [[1029, 0], [549, 0]]
# 23  0.497679  0.000000      [[560, 0], [317, 0]]
# 24  0.514769  0.000000     [[1029, 0], [549, 0]]
# 25  0.497679  0.000000      [[560, 0], [317, 0]]
# 26  0.551579 -0.010516  [[768, 261], [415, 134]]
# 27  0.539091 -0.018902   [[418, 142], [242, 75]]
# 28  0.514769  0.000000     [[1029, 0], [549, 0]]
# 29  0.497137 -0.025420      [[559, 1], [317, 0]]
# 30  0.514769  0.000000     [[1029, 0], [549, 0]]
# 31  0.497679  0.000000      [[560, 0], [317, 0]]
# 32  0.544698 -0.013963  [[702, 327], [382, 167]]
# 33  0.524817 -0.041481   [[375, 185], [225, 92]]
# 34  0.514769  0.000000     [[1029, 0], [549, 0]]
# 35  0.497679  0.000000      [[560, 0], [317, 0]]

# %% [markdown]
# ##### Analizar resultados de las metricas

# %%
metrics = ['acc', 'recall', 'precision', 'f1', 'mcc']
df_test = df_result[df_result['dataset'] == 'Test']
df_val = df_result[df_result['dataset'] == 'Validation']

# %%
def graph_models(df, dataset):
    plt.figure(figsize=(14, 8))
    sns.barplot(x='model', y='value', hue='variable', 
                data=pd.melt(df, id_vars=['model', 'scaler', 'dataset'], value_vars=metrics), 
                ci=None)
    plt.title(f'Comparación de métricas por modelo en {dataset}')
    plt.xlabel('Modelo')
    plt.ylabel('Valor de métrica')
    plt.legend(title='Métricas')
    plt.xticks(rotation=45)
    plt.show()

# %%
def graph_scaler(df, dataset):
    plt.figure(figsize=(14, 8))
    sns.barplot(x='scaler', y='value', hue='variable', 
                data=pd.melt(df, id_vars=['scaler', 'model', 'dataset'], value_vars=metrics), 
                ci=None)
    plt.title(f'Comparación de métricas por escalador en {dataset}')
    plt.xlabel('Escalador')
    plt.ylabel('Valor de métricas')
    plt.legend(title='Métricas')
    plt.xticks(rotation=45)
    plt.show()

# %%
def graph_models_scaler(df, dataset):
    melted_df = pd.melt(df, id_vars=['model', 'scaler', 'dataset'], value_vars=metrics, var_name='metric', value_name='value')
    plt.figure(figsize=(16, 8))
    sns.barplot(x='model', y='value', hue='scaler', 
                data=melted_df, 
                ci=None)
    plt.title(f'Métricas por modelo y escalador en {dataset}')
    plt.xlabel('Modelo')
    plt.ylabel('Valor de métricas')
    plt.legend(title='Escalador')
    plt.xticks(rotation=45)
    plt.show()

# %%
graph_models(df_val, "validación")

# %%
graph_models(df_test, "test")

# %%
graph_scaler(df_val, "validación")

# %%
graph_scaler(df_test, "test")

# %%
graph_models_scaler(df_val, "validación")

# %%
graph_models_scaler(df_test, "test")

# %%
best_models = pd.DataFrame()

for metric in metrics:
    best_index = df_result[metric].idxmax()
    best_model = df_result.loc[best_index]
    best_model['best_metric'] = metric
    best_models = best_models.append(best_model, ignore_index=True)

# %%
best_models
# Out:
#       dataset          scaler model       acc    recall  precision        f1  \
# 0  Validation  StandardScaler    RL  0.652091  0.652091   0.425223  0.514769
# 1  Validation  StandardScaler    RL  0.652091  0.652091   0.425223  0.514769
# 2        Test  StandardScaler   SVM  0.639681  0.639681   0.769659  0.500299
# 3  Validation    MinMaxScaler    DT  0.577313  0.577313   0.550149  0.559398
# 4        Test  StandardScaler   SVM  0.639681  0.639681   0.769659  0.500299
#
#         mcc                        cm best_metric
# 0  0.000000     [[1029, 0], [549, 0]]         acc
# 1  0.000000     [[1029, 0], [549, 0]]      recall
# 2  0.044907      [[560, 0], [316, 1]]   precision
# 3  0.008367  [[767, 262], [405, 144]]          f1
# 4  0.044907      [[560, 0], [316, 1]]         mcc
